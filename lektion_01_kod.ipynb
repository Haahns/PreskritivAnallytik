# %% [markdown]
# ### OpenAI Gym
#
# https://www.gymlibrary.dev/
#
# ### Credits
# This lecture is built on work by:
# - Leonardo A. Espinosa Ph.D.
# - Andrej Scherbakov-Parland, M.Sc.
#
# ### Bibliography:
#
# For this lecture:
#
# * Sutton, Richard S., and Andrew G. Barto. Reinforcement learning: An introduction. Ch 1. MIT press, 2020.
# http://incompleteideas.net/book/RLbook2020.pdf
#
# * AlphaGo the movie https://www.youtube.com/watch?v=WXuK6gekU1Y
#
# * Yuxi Li. Deep Reinforcement Learning, 2018.
# https://arxiv.org/abs/1810.06339
#
#
# General:
#
# * Introduction to Reinforcement Learning with David Silver - https://deepmind.com/learning-resources/-introduction-reinforcement-learning-david-silver
#
# * Bostrom, Nick. Superintelligence. Dunod, 2017.

# %%
# Install packages
# !pip install gym[all] seaborn pandas

# VS build tools for C++ 14.00 or greater for OpenAI Gym on Windows
#
# Download link:
# https://visualstudio.microsoft.com/visual-cpp-build-tools/
#
# Tested on Windows 10, Python 3.10
# Out:
# Collecting gym[all]
#   Using cached gym-0.26.2.tar.gz (721 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: seaborn in /home/kraakan/anaconda3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: pandas in /home/kraakan/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (4.11.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (2.0.0)
# Collecting gym-notices>=0.0.4
#   Using cached gym_notices-0.0.8-py3-none-any.whl (3.0 kB)
# Requirement already satisfied: numpy>=1.18.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (1.21.5)
# Requirement already satisfied: lz4>=3.1.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (3.1.3)
# Collecting pytest==7.0.1
#   Using cached pytest-7.0.1-py3-none-any.whl (296 kB)
# Collecting mujoco-py<2.2,>=2.1
#   Using cached mujoco_py-2.1.2.14-py3-none-any.whl (2.4 MB)
# Collecting opencv-python>=3.0
#   Using cached opencv_python-4.6.0.66-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (60.9 MB)
# Collecting box2d-py==2.3.5
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting moviepy>=1.0.0
#   Using cached moviepy-1.0.3.tar.gz (388 kB)
#   Preparing metadata (setup.py) ... done
# Collecting swig==4.*
#   Using cached swig-4.1.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
# Collecting ale-py~=0.8.0
#   Downloading ale_py-0.8.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 16.1 MB/s eta 0:00:0031m13.7 MB/s eta 0:00:01
# Collecting pygame==2.1.0
#   Downloading pygame-2.1.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 37.4 MB/s eta 0:00:00m eta 0:00:010:0101
# Collecting mujoco==2.2
#   Downloading mujoco-2.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 45.6 MB/s eta 0:00:00m eta 0:00:010:01
# Requirement already satisfied: imageio>=2.14.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (2.19.3)
# Requirement already satisfied: matplotlib>=3.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from gym[all]) (3.5.2)
# Collecting pyopengl
#   Using cached PyOpenGL-3.1.6-py3-none-any.whl (2.4 MB)
# Collecting glfw
#   Using cached glfw-2.5.5-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (207 kB)
# Collecting absl-py
#   Using cached absl_py-1.3.0-py3-none-any.whl (124 kB)
# Requirement already satisfied: py>=1.8.2 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (1.11.0)
# Requirement already satisfied: packaging in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (21.3)
# Requirement already satisfied: tomli>=1.0.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (2.0.1)
# Requirement already satisfied: iniconfig in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (1.1.1)
# Requirement already satisfied: attrs>=19.2.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (21.4.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pytest==7.0.1->gym[all]) (1.0.0)
# Requirement already satisfied: scipy>=1.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from seaborn) (1.9.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from pandas) (2022.1)
# Requirement already satisfied: typing-extensions in /home/kraakan/anaconda3/lib/python3.9/site-packages (from ale-py~=0.8.0->gym[all]) (4.3.0)
# Collecting importlib-resources
#   Using cached importlib_resources-5.10.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: pillow>=8.3.2 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from imageio>=2.14.1->gym[all]) (9.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.8.0->gym[all]) (3.8.0)
# Requirement already satisfied: cycler>=0.10 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->gym[all]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->gym[all]) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->gym[all]) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0->gym[all]) (4.25.0)
# Collecting decorator<5.0,>=4.0.2
#   Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from moviepy>=1.0.0->gym[all]) (4.64.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from moviepy>=1.0.0->gym[all]) (2.28.1)
# Collecting proglog<=1.0.0
#   Using cached proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Collecting imageio_ffmpeg>=0.2.0
#   Using cached imageio_ffmpeg-0.4.7-py3-none-manylinux2010_x86_64.whl (26.9 MB)
# Requirement already satisfied: Cython>=0.27.2 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from mujoco-py<2.2,>=2.1->gym[all]) (0.29.32)
# Requirement already satisfied: cffi>=1.10 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from mujoco-py<2.2,>=2.1->gym[all]) (1.15.1)
# Collecting fasteners~=0.15
#   Using cached fasteners-0.18-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.5 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pycparser in /home/kraakan/anaconda3/lib/python3.9/site-packages (from cffi>=1.10->mujoco-py<2.2,>=2.1->gym[all]) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/kraakan/anaconda3/lib/python3.9/site-packages (from requests<3.0,>=2.8.1->moviepy>=1.0.0->gym[all]) (1.26.11)
# Building wheels for collected packages: box2d-py, moviepy, gym
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp39-cp39-linux_x86_64.whl size=495325 sha256=6a2ef74e050b39291318c3493e425e4def0d8abd521f334c122f4b48bf3926e9
#   Stored in directory: /home/kraakan/.cache/pip/wheels/a4/c2/c1/076651c394f05fe60990cd85616c2d95bc1619aa113f559d7d
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110728 sha256=fdbb035e1cd1a830883fcab9e275cf5bed273d83f599fb058b9fa0c58f33d240
#   Stored in directory: /home/kraakan/.cache/pip/wheels/29/15/e4/4f790bec6acd51a00b67e8ee1394f0bc6e0135c315f8ff399a
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827636 sha256=c4579bc6c0a2f8d0c8b85ed73c2970adfd7b0b44c644985d8625a61543dbf431
#   Stored in directory: /home/kraakan/.cache/pip/wheels/af/2b/30/5e78b8b9599f2a2286a582b8da80594f654bf0e18d825a4405
# Successfully built box2d-py moviepy gym
# Installing collected packages: swig, pyopengl, gym-notices, glfw, box2d-py, pygame, proglog, opencv-python, importlib-resources, imageio_ffmpeg, fasteners, decorator, absl-py, pytest, mujoco-py, mujoco, moviepy, gym, ale-py
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
#   Attempting uninstall: pytest
#     Found existing installation: pytest 7.1.2
#     Uninstalling pytest-7.1.2:
#       Successfully uninstalled pytest-7.1.2
# Successfully installed absl-py-1.3.0 ale-py-0.8.0 box2d-py-2.3.5 decorator-4.4.2 fasteners-0.18 glfw-2.5.5 gym-0.26.2 gym-notices-0.0.8 imageio_ffmpeg-0.4.7 importlib-resources-5.10.0 moviepy-1.0.3 mujoco-2.2.0 mujoco-py-2.1.2.14 opencv-python-4.6.0.66 proglog-0.1.10 pygame-2.1.0 pyopengl-3.1.6 pytest-7.0.1 swig-4.1.0

# %% [markdown]
# ### Lunar Lander

# %%
import gym
env = gym.make("LunarLander-v2", render_mode="human")
env.action_space.seed(42)

observation, info = env.reset(seed=42)

for _ in range(500):
    observation, reward, terminated, truncated, info = env.step(env.action_space.sample())

    if terminated or truncated:
        observation, info = env.reset()

env.close()

# %% [markdown]
# # Agenten

# %%
# Sketching the agent

import numpy as np

class Agent_v0(object):
    def __init__(self):
        self.stateHistory = None

    def chooseAction(self):
        pass
    
    def updateStateHistory(self):
        pass
    
    def learn(self):
        pass

# %% [markdown]
# # Miljön

# %%
# defining our environment

# 6 x 6 matrix
# Robot enters at (0,0) - top left and Exit at (5,5) - bottom right.
# Numpy array 0s are empty, 1s are the walls (X), 2 is robot (R).

class Maze_v0(object):
    def __init__(self):
        self.maze = np.zeros((6,6))
        self.maze[5,:5] = 1
        self.maze[:4,5] = 1
        self.maze[2,2:] = 1
        self.maze[3,2] = 1
        self.maze[0,0] = 2
        self.robotPosition = (0,0)
        
    def isAllowedMove(self, state, action):
        pass

    def updateMaze(self, action):
        pass

    def isGameOver(self, state):
        pass

    def printMaze(self):
        print('------------------------------------')
        for row in self.maze:
            for col in row:
                if col==0:
                    print('-',end='\t')
                elif col==1:
                    print('X',end='\t')
                elif col==2:
                    print('R',end='\t')
            print('\n')
        print('-------------------------------------')

    def get_matrix(self):
        return self.maze

# %%
# Visa miljön

maze = Maze_v0()
maze.printMaze()
# Out:
# ------------------------------------
# R	-	-	-	-	X
#
# -	-	-	-	-	X
#
# -	-	X	X	X	X
#
# -	-	X	-	-	X
#
# -	-	-	-	-	-
#
# X	X	X	X	X	-
#
# -------------------------------------

# %% [markdown]
# # Render for humans please!

# %%
# make a much nicer plot using seaborn -> unnecessary :)

import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(8, 8))
a = maze.get_matrix()
plt.show(sns.heatmap(a,cmap="Dark2",cbar=False,linewidths=.5))

# %% [markdown]
# # Final version of the Agent
# Från vår agent skiss tidigare gör vi:
#
# - actionSpace Dictionary
#     - Hur den får röra sig (x,y) kordinater
# - chooseAction function()
#     - Möjligheten att välja en handling
#     - randomFactor! Explore vs Exploit
# - updateStateHistory function()

# %%
# Final version for the agent class.

import numpy as np 

actionSpace = {'U': (-1,0), 'D': (1,0), 'L': (0,-1), 'R': (0,1)}     # Action space, actions as movements

class Agent(object):                                                 # define my agent class    
    def __init__(self, maze, alpha=0.15, randomFactor=0.2):          # default random vales 80% exploting / 20% exploring. alpha
        self.stateHistory = [((0,0), 0)]                             # state, reward pairs. 
        self.G = {}                                                  # present value of expected future rewards      
        self.randomFactor = randomFactor
        self.alpha = alpha   
        self.initReward(maze.allowedStates)  

    def chooseAction(self, state, allowedMoves):                    # encoding physics into the environment
        maxG = -10e15                                               # basis for comparison in the first move
        nextMove = None 
        randomN = np.random.random()                                # pick a number from a random distribution, compares with random factor
        if randomN < self.randomFactor:
            nextMove = np.random.choice(allowedMoves)          
        else:            
            for action in allowedMoves:                              # iterate over the allowed moves and look for the
                newState = tuple([sum(x) for x in zip(state, actionSpace[action])]) # approximation of the  reward for                                                        
                if self.G[newState] >= maxG:                         # the new state, and then we compare it with our
                    maxG = self.G[newState]                          # best known reward
                    nextMove = action                                # if it is good we save it as our best reward and pick
        return nextMove                                              # the next move as the respective action.

    def initReward(self, allowedStates):
        for state in allowedStates:     
            self.G[state] = np.random.uniform(low=-1.0, high=-0.1)
            
            
    def updateStateHistory(self, state, reward):           # To update our stateHistory, we want to pass in the new state
        self.stateHistory.append((state, reward))          # and reward, and we simply use the append function
                                                           # to append the state reward tuple to our list.         


    def learn(self):    #this is called at the end of the episode when the agent has finished running the maze. 
        target = 0      # we only learn when we beat the maze

        for prev, reward in reversed(self.stateHistory):                    
            self.G[prev] = self.G[prev] + self.alpha * (target - self.G[prev])            
            target += reward

        self.stateHistory = []
        self.randomFactor -= 10e-5                        # decrease the random factor at every step, gradually go from exploration to exploitation.

        

    def printG(self):
        for i in range(6):            
            for j in range(6):
                if (i,j) in self.G.keys():
                    print('%.6f' % self.G[(i,j)], end='\t')
                else:
                    print('X', end='\t\t')
            print('\n')

# %% [markdown]
# # Final version of the Environment
#
# Vi modifierar vår vakra seaborn labyrint med de sista detaljerna
#
# - Ingen tunnel effekt, vi följer fysikens lagar och ser till att agenten inte kan röra sig utanför "sin" värld eller gå in/igenom väggar.
# - Vi sätter in tillåtna handlingar (actionSpace) i miljön
#
# Detta är ett av de enklare sätten att lösa labyrinten, dock abosolut inte det mest effektiva.

# %%
# final version for the environment, aka Maze
# Define allowed moves, construct allowed states, game over function, get state, print maze and update maze.

# Aditional functionalities
# - Keep track of the number of steps
# - Check game over.
# - Get state / reward.
# - Print the maze

import numpy as np
actionSpace = {'U': (-1,0), 'D': (1,0), 'L': (0,-1), 'R': (0,1)}  # action space

class Maze(object):
    def __init__(self):        
        self.maze = np.zeros((6,6)) # 6x6 maze - exit at 5,5
        self.maze[5, :5] = 1 
        self.maze[:4, 5] = 1
        self.maze[2, 2:] = 1
        self.maze[3,2] = 1
        self.maze[0,0] = 2
        self.robotPosition = (0,0)
        self.steps = 0                                          # initial steps to zero
        self.constructAllowedStates()                           # construct the allowed states

    def printMaze(self):
        print('------------------------------------------')
        for row in self.maze:      
            for col in row:
                if col == 0:                                    # empty spaces
                    print('', end='\t')
                elif col == 1:                                  # walls
                    print('X', end='\t')
                elif col == 2:                                  # robot
                    print('R', end='\t')                    
            print('\n')
        print('------------------------------------------')       
    
    def isAllowedMove(self, state, action):
        y, x = state
        y += actionSpace[action][0]                             # extract the coordinates from the action space
        x += actionSpace[action][1]
        if y < 0 or x < 0 or y > 5 or x > 5:                    # check if the move is allowed, inside the maze
            return False

        if self.maze[y,x] == 0 or self.maze[y,x] == 2:          #check if the new state is zero (or the actual position of the robot, because not moving is valid)
            return True
        else:
            return False

    def constructAllowedStates(self):                           # construct a dictionary and loop over the maze
        allowedStates= {}
        for y, row in enumerate(self.maze):
            for x, col in enumerate(row):                
                if self.maze[(y,x)] != 1:                       # It goes space by space checking if the actions are allowed, if yes it appended to allowed states dictionary
                    allowedStates[(y,x)] = []
                    for action in actionSpace:
                        if self.isAllowedMove((y,x), action):
                            allowedStates[(y,x)].append(action)
        self.allowedStates = allowedStates

    def updateMaze(self, action):                              
        y,x = self.robotPosition
        self.maze[y,x] = 0                                       # Get the current position of the robot and set to 0
        y += actionSpace[action][0]                              # read the coordinates from the action space diccionary 
        x += actionSpace[action][1]               
        self.robotPosition = (y,x)                               # updates the position of the robot
        self.maze[y,x] = 2                                       # update the mze
        self.steps += 1                                          # adds a new step

    def isGameOver(self):                                        # Check if the position is in the exit.
        if self.robotPosition == (5,5):
            return True
        else:
            return False
    
    def getStateAndReward(self):                                 
        reward = self.giveReward()
        return self.robotPosition, reward

    def giveReward(self):                                        # Gives the reward of 0 if the robots is in the exit.
        if self.robotPosition == (5,5):
            return 0
        else:
            return -1
        
    def get_matrix(self):
        return self.maze

# %% [markdown]
# ## Vad har vi gjort?
# Att lösa labyrinten med vår agent är en god utgångspunkt till svårare problem.
#
# Vi har täckt de väsentliga begreppen för förstärkt lärande (*RL*) och skapat något som lär sig från de första principerna.
#
# Allt agenter egentligen behöver är ett internt minne av tillstånds- (state-) och belöningsparen (rewardpairs); en uppskattning av de förväntade framtida belöningarna (*G*) och någon mekanism för att då och då välja slumpmässiga åtgärder för att testa dess modell av världen (*Explore vs Exploit*).

# %% [markdown]
# # Main function to use our Agent + Maze from above
#
#
# - Två agenter
# - 5000 matcher
# - Prova 𝛼 = 0.1 och  𝛼 =0.99
# - Vi väljer en slumpmässig faktor av 0.2.
# - Vi ritar ut hur många steg det tar varje robot att klara en episod.

# %%
# Let's create our main function

import numpy as np
import matplotlib.pyplot as plt 

maze = Maze()
robot = Agent(maze, alpha=0.1, randomFactor=0.2)
moveHistory = []      # keep track of the number of moves.
for i in range(5000): # number of games
    if i % 1000 == 0:
        print(i)      # just to know is running.
    while not maze.isGameOver():     # while the game is not over
        state, _ = maze.getStateAndReward()   # gets state and reward
        action = robot.chooseAction(state, maze.allowedStates[state]) # update the actions
        maze.updateMaze(action)
        state, reward = maze.getStateAndReward()
        robot.updateStateHistory(state, reward)
        if maze.steps > 1000:                  # cut prematurely to avoid infinite looping
            maze.robotPosition = (5,5)
    robot.learn()                              # learns
    moveHistory.append(maze.steps)             # keep tracking of steps
    maze = Maze()                              # resets the maze but not the agent.

maze = Maze()
robot = Agent(maze, alpha=0.99, randomFactor=0.2)
moveHistory2 = []
for i in range(5000):
    if i % 1000 == 0:
        print(i)
    while not maze.isGameOver():
        state, _ = maze.getStateAndReward()
        action = robot.chooseAction(state, maze.allowedStates[state])
        maze.updateMaze(action)
        state, reward = maze.getStateAndReward()
        robot.updateStateHistory(state, reward)
        if maze.steps > 1000:
            maze.robotPosition = (5,5)            
    robot.learn()
    moveHistory2.append(maze.steps)
    maze = Maze()
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 0
# 1000
# 2000
# 3000
# 4000

# %%
# A plot to show how our agent is doing!
plt.figure(figsize=(16, 8))
plt.subplot(211)
plt.semilogy(moveHistory, 'b--')
plt.legend(['alpha=0.1'])
plt.subplot(212)
plt.semilogy(moveHistory2, 'r--')
plt.legend(['alpha=0.99'])
plt.show()
